# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1

# %%
a = "hello"
b = []
for i in a[::-1]:
  b += i
  print (b)
# Out:
# ['o']
# ['o', 'l']
# ['o', 'l', 'l']
# ['o', 'l', 'l', 'e']
# ['o', 'l', 'l', 'e', 'h']

# %%
a = "hello"
b = ""
for i in a[::-1]:
  b += i
  print (b)
# Out:
# o
# ol
# oll
# olle
# olleh
