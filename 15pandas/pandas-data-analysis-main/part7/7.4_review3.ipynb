# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv'
#데이터읽기
df=pd.read_csv(url)
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')
df=df.dropna()

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.select_dtypes(exclude='object').corr
# Out:
# <bound method DataFrame.corr of       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 0                 0       1           29.85         29.85
# 1                 0      34           56.95       1889.50
# 2                 0       2           53.85        108.15
# 3                 0      45           42.30       1840.75
# 4                 0       2           70.70        151.65
# ...             ...     ...             ...           ...
# 7038              0      24           84.80       1990.50
# 7039              0      72          103.20       7362.90
# 7040              0      11           29.60        346.45
# 7041              1       4           74.40        306.60
# 7042              0      66          105.65       6844.50
#
# [7032 rows x 4 columns]>

# %%
# tenure에 따른 이탈률
import seaborn as sns
sns.histplot(data=df, x='tenure', hue='Churn', multiple='fill')
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(data=df, x='Contract', hue='Churn', multiple='fill')
# Out:
# <Axes: xlabel='Contract', ylabel='Count'>

# %%
# baseline에서 상관관게로 total.. 변수 제거한 모델에 + tenure, Contract를 범주형 데이터로 변환하고 onehot으로 변경
df.tenure.hist()
df.tenure = pd.qcut(df.tenure, q=4, labels=[0,1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 df.tenure.hist()
#       3 df.tenure = pd.qcut(df.tenure, q=4, labels=[0,1,2,3])
# ----> 4 df.Contract = pd.qcut(df.Contract, q=3, labels=[0,1,2])
#
# File d:\0python_SNC\streamlit_prj\Lib\site-packages\pandas\core\reshape\tile.py:338, in qcut(x, q, labels, retbins, precision, duplicates)
#     334 x_idx, _ = _coerce_to_type(x_idx)
#     336 quantiles = np.linspace(0, 1, q + 1) if is_integer(q) else q
# --> 338 bins = x_idx.to_series().dropna().quantile(quantiles)
#     340 fac, bins = _bins_to_cuts(
#     341     x_idx,
#     342     Index(bins),
#    (...)    346     duplicates=duplicates,
#     347 )
#     349 return _postprocess_for_cut(fac, bins, retbins, original)
#
# File d:\0python_SNC\streamlit_prj\Lib\site-packages\pandas\core\series.py:2898, in Series.quantile(self, q, interpolation)
# ...
